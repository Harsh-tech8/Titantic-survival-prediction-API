# %%
import requests

data = {
    "features": [3, 1, 22, 0,  7.25]
}

response = requests.post(
    "http://127.0.0.1:5000/predict",
    json=data
)

print(response.status_code)
print("Status:", response.status_code)
print("Response:")
print(response.text)
# Out:
# 200
# Status: 200
# Response:
# {"prediction":[0]}
